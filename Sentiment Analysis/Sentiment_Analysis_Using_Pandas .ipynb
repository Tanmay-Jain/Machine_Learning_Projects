# %% [markdown]
# # Analyzing product sentiment using Pandas
#
# ### What is Sentiment Analysis?
#
# Sentiment Analysis is a field within Natural Language Processing (NLP) concerned with identifying and classifying subjective opinions from text. Sentiment analysis ranges from detecting emotions (e.g., anger, happiness, fear), to sarcasm and intent (e.g., complaints, feedback, opinions). In its simplest form, sentiment analysis assigns a polarity (e.g., positive, negative, neutral) to a piece of text.
#
#
# ### Project Description:
#
# How do you guess whether a person felt positively or negatively about an experience, just from a short review they wrote?
#
# Here, analyzed sentiments, created models that predict a class (positive/negative sentiment) from input features (text of the reviews, user profile information).
#
# This project is an example of classification.
#
# Implemented logistic regression classifier, analyzed the accuracy of classifier and found out the most positive and negative reviews.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exploring Data

# %%
df = pd.read_csv('amazon_baby.csv')

# %%
df.shape
# Out:
# (183531, 3)

# %%
df.head(20)
# Out:
#                                                  name  \
# 0                            Planetwise Flannel Wipes
# 1                               Planetwise Wipe Pouch
# 2                 Annas Dream Full Quilt with 2 Shams
# 3   Stop Pacifier Sucking without tears with Thumb...
# 4   Stop Pacifier Sucking without tears with Thumb...
# 5   Stop Pacifier Sucking without tears with Thumb...
# 6            A Tale of Baby\'s Days with Peter Rabbit
# 7   Baby Tracker&reg; - Daily Childcare Journal, S...
# 8   Baby Tracker&reg; - Daily Childcare Journal, S...
# 9   Baby Tracker&reg; - Daily Childcare Journal, S...
# 10  Baby Tracker&reg; - Daily Childcare Journal, S...
# 11  Baby Tracker&reg; - Daily Childcare Journal, S...
# 12  Baby Tracker&reg; - Daily Childcare Journal, S...
# 13  Baby Tracker&reg; - Daily Childcare Journal, S...
# 14    Nature\'s Lullabies First Year Sticker Calendar
# 15    Nature\'s Lullabies First Year Sticker Calendar
# 16    Nature\'s Lullabies First Year Sticker Calendar
# 17   Nature\'s Lullabies Second Year Sticker Calendar
# 18   Nature\'s Lullabies Second Year Sticker Calendar
# 19   Nature\'s Lullabies Second Year Sticker Calendar
#
#                                                review  rating
# 0   These flannel wipes are OK, but in my opinion ...       3
# 1   it came early and was not disappointed. i love...       5
# 2   Very soft and comfortable and warmer than it l...       5
# 3   This is a product well worth the purchase.  I ...       5
# 4   All of my kids have cried non-stop when I trie...       5
# 5   When the Binky Fairy came to our house, we did...       5
# 6   Lovely book, it\'s bound tightly so you may no...       4
# 7   Perfect for new parents. We were able to keep ...       5
# 8   A friend of mine pinned this product on Pinter...       5
# 9   This has been an easy way for my nanny to reco...       4
# 10  I love this journal and our nanny uses it ever...       4
# 11  This book is perfect!  I\'m a first time new m...       5
# 12  I originally just gave the nanny a pad of pape...       4
# 13  I thought keeping a simple handwritten journal...       3
# 14  Space for monthly photos, info and a lot of us...       5
# 15  I bought this calender for myself for my secon...       4
# 16  I love this little calender, you can keep trac...       5
# 17  This was the only calender I could find for th...       5
# 18  I completed a calendar for my son\'s first yea...       4
# 19  We wanted to get something to keep track of ou...       5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183531 entries, 0 to 183530
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   name    183213 non-null  object
#  1   review  182702 non-null  object
#  2   rating  183531 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 4.2+ MB

# %%
df.isnull().sum()
# Out:
# name      318
# review    829
# rating      0
# dtype: int64

# %% [markdown]
# ## Text Cleaning

# %%
df = df.fillna({'review':''})

# %%
def remove_punctuation(text):
    import string
    return text.translate(str.maketrans('','',string.punctuation))

df['review_clean'] = df['review'].apply(remove_punctuation)

# %%
df.head()
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating  \
# 0  These flannel wipes are OK, but in my opinion ...       3
# 1  it came early and was not disappointed. i love...       5
# 2  Very soft and comfortable and warmer than it l...       5
# 3  This is a product well worth the purchase.  I ...       5
# 4  All of my kids have cried non-stop when I trie...       5
#
#                                         review_clean
# 0  These flannel wipes are OK but in my opinion n...
# 1  it came early and was not disappointed i love ...
# 2  Very soft and comfortable and warmer than it l...
# 3  This is a product well worth the purchase  I h...
# 4  All of my kids have cried nonstop when I tried...

# %% [markdown]
# ## Extract Sentiments

# %%
df = df[df['rating'] != 3]

# %%
df['sentiment'] = df['rating'].apply(lambda rating : +1 if rating > 3 else -1)

# %%
df.head()
# Out:
#                                                 name  \
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
# 5  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating  \
# 1  it came early and was not disappointed. i love...       5
# 2  Very soft and comfortable and warmer than it l...       5
# 3  This is a product well worth the purchase.  I ...       5
# 4  All of my kids have cried non-stop when I trie...       5
# 5  When the Binky Fairy came to our house, we did...       5
#
#                                         review_clean  sentiment
# 1  it came early and was not disappointed i love ...          1
# 2  Very soft and comfortable and warmer than it l...          1
# 3  This is a product well worth the purchase  I h...          1
# 4  All of my kids have cried nonstop when I tried...          1
# 5  When the Binky Fairy came to our house we didn...          1

# %% [markdown]
# ## Split into training and test sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['sentiment']), df['sentiment'], test_size=0.20, random_state=42)

# %% [markdown]
# ## Build the word count vector for each review

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(token_pattern=r'\b\w+\b')
# Use this token pattern to keep single-letter words
# First, learn vocabulary from the training data and assign columns to words
# Then convert the training data into a sparse matrix
train_matrix = vectorizer.fit_transform(X_train['review_clean'])
# Second, convert the test data into a sparse matrix, using the same word-column mapping
test_matrix = vectorizer.transform(X_test['review_clean'])
#print vectorizer.vocabulary_

# %% [markdown]
# ## Train a sentiment classifier with logistic regression

# %%
from sklearn.linear_model import LogisticRegression
sentiment_model = LogisticRegression()
sentiment_model.fit(train_matrix, y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
predicted_y = sentiment_model.predict(test_matrix)
correct_num = np.sum(predicted_y == y_test)
total_num = len(y_test)
print("correct_num: {}, total_num: {}".format(correct_num, total_num))
accuracy = correct_num * 1./ total_num
print(accuracy)
# Out:
# correct_num: 31169, total_num: 33351
# 0.9345746754220263

# %% [markdown]
# ## Probability Predictions

# %%
predicted_probability = sentiment_model.predict_proba(test_matrix)

# %%
result = X_test.copy()
result['actual_sentiment'] = y_test

# %%
result['predicted_sentiment']= predicted_y

# %%
result['negative_class_probability']= predicted_probability[:,0]
result['positive_class_probability']= predicted_probability[:,1]

# %%
result.head()
# Out:
#                                                      name  \
# 146345        Inglesina 2013 Fast Table Chair, Liquirizia
# 80867                       Tiny Love Island Stroller Set
# 148242              Munchkin Bath Fun Bubble Blower, Blue
# 162192  Kidsline Disney Pooh and Friends Collection Se...
# 141236  PRK Products Inc Universal Baby Bottle and Sip...
#
#                                                    review  rating  \
# 146345  Not easy to use and didn\'t fit any of the tab...       1
# 80867   NOT WHAT I EXPECTED. THEY SHOWING IT LIKE IT\'...       1
# 148242  The tip about taping half the air output port ...       2
# 162192  A bit smaller than I had anticipated but my in...       4
# 141236  I just bought this for my grandson.  His mom l...       5
#
#                                              review_clean  actual_sentiment  \
# 146345  Not easy to use and didnt fit any of the table...                -1
# 80867   NOT WHAT I EXPECTED THEY SHOWING IT LIKE ITS A...                -1
# 148242  The tip about taping half the air output port ...                -1
# 162192  A bit smaller than I had anticipated but my in...                 1
# 141236  I just bought this for my grandson  His mom lo...                 1
#
#         predicted_sentiment  positive_class_probability  \
# 146345                    1                    0.654219
# 80867                    -1                    0.268006
# 148242                   -1                    0.303242
# 162192                    1                    0.999063
# 141236                    1                    0.994243
#
#         negative_class_probability
# 146345                    0.345781
# 80867                     0.731994
# 148242                    0.696758
# 162192                    0.000937
# 141236                    0.005757

# %% [markdown]
# ## Finding the most positive and negative review

# %%
# most positive review 
result[result['positive_class_probability'] == result['positive_class_probability'].max()]
# Out:
#                                                      name  \
# 123632    Zooper 2011 Waltz Standard Stroller, Flax Brown
# 135152  Maxi-Cosi Pria 70 with Tiny Fit Convertible Ca...
# 50735   Joovy Zoom 360 Swivel Wheel Jogging Stroller, ...
# 100166  Infantino Wrap and Tie Baby Carrier, Black Blu...
# 166409                 Kiddy City N Move Stroller, Walnut
# 109574  phil&amp;teds Smart Buggy Bassinet and Strolle...
# 111155  bumGenius One-Size Hook &amp; Loop Closure Clo...
# 57108                  BabyPlus Prenatal Education System
# 129722  Bumbleride 2011 Flite Lightweight Compact Trav...
# 168086  Buttons Cloth Diaper Cover - One Size - 8 Colo...
#
#                                                    review  rating  \
# 123632  I did a TON of research before I purchased thi...       5
# 135152  We\'ve been using Britax for our boy (now 14 m...       5
# 50735   The joovy zoom 360 was the perfect solution fo...       5
# 100166  I bought this carrier when my daughter was abo...       5
# 166409  For starters, it\'s the only stroller my littl...       4
# 109574  My wife\'s 5\', and I\'m about 5\'6", our baby...       5
# 111155  We did my son in cloth diapers from birth thro...       5
# 57108   I started wearing the Babyplus when I was 18 w...       5
# 129722  This is a review of the 2012 Bumbleride Flite ...       5
# 168086  Buttons vs. Best Bottoms reviewFirst thing I w...       5
#
#                                              review_clean  actual_sentiment  \
# 123632  I did a TON of research before I purchased thi...                 1
# 135152  Weve been using Britax for our boy now 14 mont...                 1
# 50735   The joovy zoom 360 was the perfect solution fo...                 1
# 100166  I bought this carrier when my daughter was abo...                 1
# 166409  For starters its the only stroller my little g...                 1
# 109574  My wifes 5 and Im about 56 our baby is within ...                 1
# 111155  We did my son in cloth diapers from birth thro...                 1
# 57108   I started wearing the Babyplus when I was 18 w...                 1
# 129722  This is a review of the 2012 Bumbleride Flite ...                 1
# 168086  Buttons vs Best Bottoms reviewFirst thing I wa...                 1
#
#         predicted_sentiment  positive_class_probability  \
# 123632                    1                         1.0
# 135152                    1                         1.0
# 50735                     1                         1.0
# 100166                    1                         1.0
# 166409                    1                         1.0
# 109574                    1                         1.0
# 111155                    1                         1.0
# 57108                     1                         1.0
# 129722                    1                         1.0
# 168086                    1                         1.0
#
#         negative_class_probability
# 123632                         0.0
# 135152                         0.0
# 50735                          0.0
# 100166                         0.0
# 166409                         0.0
# 109574                         0.0
# 111155                         0.0
# 57108                          0.0
# 129722                         0.0
# 168086                         0.0

# %%
# most negative reviews
result[result['negative_class_probability'] == result['negative_class_probability'].max()]
# Out:
#                                             name  \
# 175191  Zooper Twist Escape Stroller, Summer Day
# 147902     Graco Pack \'n Play Playard - Dempsey
#
#                                                    review  rating  \
# 175191  I had to return this stroller for three reason...       1
# 147902  My disappointment with this product prompted m...       1
#
#                                              review_clean  actual_sentiment  \
# 175191  I had to return this stroller for three reason...                -1
# 147902  My disappointment with this product prompted m...                -1
#
#         predicted_sentiment  positive_class_probability  \
# 175191                   -1                7.871137e-18
# 147902                   -1                2.189015e-21
#
#         negative_class_probability
# 175191                         1.0
# 147902                         1.0
